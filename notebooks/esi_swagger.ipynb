# %%
from __future__ import print_function
import time
import swagger_client
from swagger_client.rest import ApiException
from pprint import pprint

# create an instance of the API class
api_instance = swagger_client.AllianceApi(swagger_client.ApiClient())
datasource = 'tranquility' # str | The server name you would like data from (optional) (default to tranquility)
if_none_match = 'if_none_match_example' # str | ETag from a previous request. A 304 will be returned if this matches the current ETag (optional)

# try:
#     # List all alliances
#     api_response = api_instance.get_alliances(datasource=datasource, if_none_match=if_none_match)
#     pprint(api_response)
# except ApiException as e:
#     print("Exception when calling AllianceApi->get_alliances: %s\n" % e)
    
api_instance2 = swagger_client.ContractsApi(swagger_client.ApiClient())

# region_id = 10000002 # int | An EVE region id (required)

api_response2 = api_instance2.get_contracts_public_region_id_with_http_info(region_id, datasource=datasource, if_none_match=if_none_match)

display(api_response2)
# Out:
# ([{'buyout': None,
#    'collateral': 0.0,
#    'contract_id': 191475785,
#    'date_expired': datetime.datetime(2023, 5, 24, 20, 42, 28, tzinfo=tzutc()),
#    'date_issued': datetime.datetime(2023, 4, 26, 20, 42, 28, tzinfo=tzutc()),
#    'days_to_complete': 0,
#    'end_location_id': 60003760,
#    'for_corporation': None,
#    'issuer_corporation_id': 98718664,
#    'issuer_id': 97109845,
#    'price': 9000000.0,
#    'reward': 0.0,
#    'start_location_id': 60003760,
#    'title': 'x 10',
#    'type': 'item_exchange',
#    'volume': 0.01},
#   {'buyout': None,
#    'collateral': 0.0,
#    'contract_id': 191476029,
#    'date_expired': datetime.datetime(2023, 5, 24, 20, 52, 20, tzinfo=tzutc()),
#    'date_issued': datetime.datetime(2023, 4, 26, 20, 52, 20, tzinfo=tzutc()),
#    'days_to_complete': 0,
#    'end_location_id': 60003760,
#    'for_corporation': None,
#    'issuer_corporation_id': 1000107,
#    'issuer_id': 93088657,
#    'price': 36000000.0,
#    'reward': 0.0,
# ...

# %%
api_instance3 = swagger_client.UniverseApi(swagger_client.ApiClient())

api_response3 = api_instance3.get_universe_regions(datasource=datasource, if_none_match=if_none_match)

# %%
display(len(api_response3))
# Out:
# 111
